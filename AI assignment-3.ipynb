# %% [markdown]
# 1.Read mobile dataset using pandas, and preprocess it (fill null values).

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\SAIDEEPTHI\Downloads\mobile_cleaned-1549119762886_-452616671.csv")

# %%
df
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0           0        12        55   155.0          250.0                  1.3
# 1           0         1        55   132.0          300.0                  1.3
# 2           0         9        55   142.0          329.0                  1.5
# 3           0         8        55   152.0          385.0                  1.3
# 4           1         1        55   234.0          385.0                  1.3
# ..        ...       ...       ...     ...            ...                  ...
# 104         3        10        14   192.0          540.0                  1.8
# 105         0         5         3   157.0          400.0                  2.3
# 106         3        10         6   192.0          384.0                  1.8
# 107         3        10        12   129.0          250.0                  1.4
# 108         2         8         3   158.0          400.0                  2.2
#
# ...

# %%
df.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               1
# stand_by_time                        3
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    2
# os                                   0
# phone_height                         1
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            1
# video_resolution                     1
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %%
df = df.fillna(df.mean())

# %%
df.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %%
df
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0           0        12        55   155.0          250.0                  1.3
# 1           0         1        55   132.0          300.0                  1.3
# 2           0         9        55   142.0          329.0                  1.5
# 3           0         8        55   152.0          385.0                  1.3
# 4           1         1        55   234.0          385.0                  1.3
# ..        ...       ...       ...     ...            ...                  ...
# 104         3        10        14   192.0          540.0                  1.8
# 105         0         5         3   157.0          400.0                  2.3
# 106         3        10         6   192.0          384.0                  1.8
# 107         3        10        12   129.0          250.0                  1.4
# 108         2         8         3   158.0          400.0                  2.2
#
# ...

# %% [markdown]
# 2.Draw correlation graph for mobile price with all attributes.

# %%
import matplotlib.pyplot as plt
x = df["price"]
y = df["sim_type"]
plt.plot(x,y)
plt.title("price vs sim_type")
plt.xlabel("price")
plt.ylabel("sim_type")
# Out:
# Text(0, 0.5, 'sim_type')

# %%
y = df["aperture"]
plt.plot(x,y)
plt.title("price vs aperture")
plt.xlabel("price")
plt.ylabel("aperture")
# Out:
# Text(0, 0.5, 'aperture')

# %%
y = df["gpu_rank"]
plt.plot(x,y)
plt.title("price vs gpu_rank")
plt.xlabel("price")
plt.ylabel("gpu_rank")
# Out:
# Text(0, 0.5, 'gpu_rank')

# %%
y = df["weight"]
plt.plot(x,y)
plt.title("price vs weight")
plt.xlabel("price")
plt.ylabel("weight")
# Out:
# Text(0, 0.5, 'weight')

# %%
y = df["stand_by_time"]
plt.plot(x,y)
plt.title("price vs stand_by_time")
plt.xlabel("price")
plt.ylabel("stand_by_time")
# Out:
# Text(0, 0.5, 'stand_by_time')

# %%
y = df["processor_frequency"]
plt.plot(x,y)
plt.title("price vs processor_frequency")
plt.xlabel("price")
plt.ylabel("processor_frequency")
# Out:
# Text(0, 0.5, 'processor_frequency')

# %%
y = df["thickness"]
plt.plot(x,y)
plt.title("price vs thickness")
plt.xlabel("price")
plt.ylabel("thickness")
# Out:
# Text(0, 0.5, 'thickness')

# %%
y = df["flash_type"]
plt.plot(x,y)
plt.title("price vs flash_type")
plt.xlabel("price")
plt.ylabel("flash_type")
# Out:
# Text(0, 0.5, 'flash_type')

# %%
y = df["front_camera_resolution"]
plt.plot(x,y)
plt.title("price vs front_camera_resolution")
plt.xlabel("price")
plt.ylabel("front_camera_resolution")
# Out:
# Text(0, 0.5, 'front_camera_resolution')

# %%
y = df["auto_focus"]
plt.plot(x,y)
plt.title("price vs auto_focus")
plt.xlabel("price")
plt.ylabel("auto_focus")
# Out:
# Text(0, 0.5, 'auto_focus')

# %%
y = df["screen_size"]
plt.plot(x,y)
plt.title("price vs screen_size")
plt.xlabel("price")
plt.ylabel("screen_size")
# Out:
# Text(0, 0.5, 'screen_size')

# %%
y = df["frames_per_second"]
plt.plot(x,y)
plt.title("price vs frames_per_second")
plt.xlabel("price")
plt.ylabel("frames_per_second")
# Out:
# Text(0, 0.5, 'frames_per_second')

# %%
y = df["FM"]
plt.plot(x,y)
plt.title("price vs FM")
plt.xlabel("price")
plt.ylabel("FM")
# Out:
# Text(0, 0.5, 'FM')

# %%
y = df["no_of_reviews_in_gsmarena_in_week"]
plt.plot(x,y)
plt.title("price vs no_of_reviews_in_gsmarena_in_week")
plt.xlabel("price")
plt.ylabel("no_of_reviews_in_gsmarena_in_week")
# Out:
# Text(0, 0.5, 'no_of_reviews_in_gsmarena_in_week')

# %%
y = df["os"]
plt.plot(x,y)
plt.title("price vs os")
plt.xlabel("price")
plt.ylabel("os")
# Out:
# Text(0, 0.5, 'os')

# %%
y = df["phone_height"]
plt.plot(x,y)
plt.title("price vs phone_height")
plt.xlabel("price")
plt.ylabel("phone_height")
# Out:
# Text(0, 0.5, 'phone_height')

# %%
y = df["screen_protection"]
plt.plot(x,y)
plt.title("price vs screen_protection")
plt.xlabel("price")
plt.ylabel("screen_protection")
# Out:
# Text(0, 0.5, 'screen_protection')

# %%
y = df["sim_size"]
plt.plot(x,y)
plt.title("price vs sim_size")
plt.xlabel("price")
plt.ylabel("sim_size")
# Out:
# Text(0, 0.5, 'sim_size')

# %%
y = df["talk_time"]
plt.plot(x,y)
plt.title("price vs talk_time")
plt.xlabel("price")
plt.ylabel("talk_time")
# Out:
# Text(0, 0.5, 'talk_time')

# %%
y = df["video_resolution"]
plt.plot(x,y)
plt.title("price vs video_resolution")
plt.xlabel("price")
plt.ylabel("video_resolution")
# Out:
# Text(0, 0.5, 'video_resolution')

# %%
y = df["display_resolution"]
plt.plot(x,y)
plt.title("price vs display_resolution")
plt.xlabel("price")
plt.ylabel("display_resolution")
# Out:
# Text(0, 0.5, 'display_resolution')

# %%
y = df["removable_battery"]
plt.plot(x,y)
plt.title("price vs removable_battery")
plt.xlabel("price")
plt.ylabel("removable_battery")
# Out:
# Text(0, 0.5, 'removable_battery')

# %%
y = df["display_type"]
plt.plot(x,y)
plt.title("price vs display_type")
plt.xlabel("price")
plt.ylabel("display_type")
# Out:
# Text(0, 0.5, 'display_type')

# %%
y = df["primary_camera_resolution"]
plt.plot(x,y)
plt.title("price vs primary_camera_resolution")
plt.xlabel("price")
plt.ylabel("primary_camera_resolution")
# Out:
# Text(0, 0.5, 'primary_camera_resolution')

# %%
y = df["battery_type"]
plt.plot(x,y)
plt.title("price vs battery_type")
plt.xlabel("price")
plt.ylabel("battery_type")
# Out:
# Text(0, 0.5, 'battery_type')

# %%
y = df["ram_memory"]
plt.plot(x,y)
plt.title("price vs ram_memory")
plt.xlabel("price")
plt.ylabel("ram_memory")
# Out:
# Text(0, 0.5, 'ram_memory')

# %%
y = df["internal_memory"]
plt.plot(x,y)
plt.title("price vs internal_memory")
plt.xlabel("price")
plt.ylabel("internal_memory")
# Out:
# Text(0, 0.5, 'internal_memory')

# %%
y = df["brand_rank"]
plt.plot(x,y)
plt.title("price vs brand_rank")
plt.xlabel("price")
plt.ylabel("brand_rank")
# Out:
# Text(0, 0.5, 'brand_rank')

# %%
y = df["no_of_cores"]
plt.plot(x,y)
plt.title("price vs no_of_cores")
plt.xlabel("price")
plt.ylabel("no_of_cores")
# Out:
# Text(0, 0.5, 'no_of_cores')

# %%
y = df["micro_sd_slot"]
plt.plot(x,y)
plt.title("price vs micro_sd_slot")
plt.xlabel("price")
plt.ylabel("micro_sd_slot")
# Out:
# Text(0, 0.5, 'micro_sd_slot')

# %%
y = df["screen_pixel_density"]
plt.plot(x,y)
plt.title("price vs screen_pixel_density")
plt.xlabel("price")
plt.ylabel("screen_pixel_density")
# Out:
# Text(0, 0.5, 'screen_pixel_density')

# %%
y = df["water_proof_rate"]
plt.plot(x,y)
plt.title("price vs water_proof_rate")
plt.xlabel("price")
plt.ylabel("water_proof_rate")
# Out:
# Text(0, 0.5, 'water_proof_rate')

# %%
y = df["phone_width"]
plt.plot(x,y)
plt.title("price vs phone_width")
plt.xlabel("price")
plt.ylabel("phone_width")
# Out:
# Text(0, 0.5, 'phone_width')

# %%
y = df["expandable_memory"]
plt.plot(x,y)
plt.title("price vs expandable_memory")
plt.xlabel("price")
plt.ylabel("expandable_memory")
# Out:
# Text(0, 0.5, 'expandable_memory')

# %%
y = df["version"]
plt.plot(x,y)
plt.title("price vs version")
plt.xlabel("price")
plt.ylabel("version")
# Out:
# Text(0, 0.5, 'version')

# %%
y = df["usb_type"]
plt.plot(x,y)
plt.title("price vs usb_type")
plt.xlabel("price")
plt.ylabel("usb_type")
# Out:
# Text(0, 0.5, 'usb_type')

# %%
y = df["battery_capacity"]
plt.plot(x,y)
plt.title("price vs battery_capacity")
plt.xlabel("price")
plt.ylabel("battery_capacity")
# Out:
# Text(0, 0.5, 'battery_capacity')

# %%
y = df["processor_rank"]
plt.plot(x,y)
plt.title("price vs processor_rank")
plt.xlabel("price")
plt.ylabel("processor_rank")
# Out:
# Text(0, 0.5, 'processor_rank')

# %%
y = df["is_liked"]
plt.plot(x,y)
plt.title("price vs is_liked")
plt.xlabel("price")
plt.ylabel("is_liked")
# Out:
# Text(0, 0.5, 'is_liked')

# %% [markdown]
# 3.Compute outer product of 2 vectors.

# %%
import numpy as np

# %%
p = [[1,0],[0,1]]
q = [[1,2],[3,4]]
print("Given arrays:")
print(p)
print(q)
r = np.outer(p,q)
print("Outer product of two vectors:")
print(r)
# Out:
# Given arrays:
# [[1, 0], [0, 1]]
# [[1, 2], [3, 4]]
# Outer product of two vectors:
# [[1 2 3 4]
#  [0 0 0 0]
#  [0 0 0 0]
#  [1 2 3 4]]

# %% [markdown]
# 4.Write a NumPy program to compute the condition number of a given matrix.
# Original matrix:

# %%
import numpy as np
from numpy import linalg as L
a = np.array([[1,2],[3,4]])
print("Condition number of given matrix: ",L.cond(a))
# Out:
# Condition number of given matrix:  14.933034373659268

# %% [markdown]
# 5.Write a NumPy program to compute the sum of the diagonal element of a given array(matrix).

# %%
t = np.array([[0,1,2],[3,4,5]])
print("Given Matrix: ")
print(t)
r = np.trace(t)
print("Trace of given matrix:",r)
# Out:
# Given Matrix:
# [[0 1 2]
#  [3 4 5]]
# Trace of given matrix: 4
